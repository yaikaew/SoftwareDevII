# %%
import requests
from bs4 import BeautifulSoup


# Make a request to the webpage
url = 'http://klogic.kmutnb.ac.th:8080/kris/tess/dataQuerySelector.jsp?query=examTab'
response = requests.get(url)
print(response.text)
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the table with the specified HTML code
table = soup.find('table', {'align': 'center', 'border': '1', 'cellpadding': '2', 'cellspacing': '0', 'width': '100%', 'bordercolor': '#CCCCCC'})

# Print the table content
print(table)
# Out:
# <style type="text/css">
# <!--
# body { font-family: "MS Sans Serif", "Microsoft Sans Serif"; font-size: 10pt}
# a:link { color:#0000FF; text-decoration:none }
# a:visited { color:#0000FF; text-decoration:none }
# a:active { color:#0099FF; text-decoration:underline }
# a:hover { color:#0099FF; text-decoration:underline }
# td { font-family: "MS Sans Serif", "Microsoft Sans Serif"; font-size: 10pt}
# -->
# </style>
#
# <center>
# <table border="0" cellpadding="2" cellspacing="3">
# <tr align="center">
# 	<td colspan="5"><font size="+1"><b>สอบถามข้อมูล</b></font></td>
# </tr>
# <tr align="center">
# 	<td><b>|</b> <a href="dataQuerySelector.jsp?query=teachTab" target="detail"><b>ตารางสอน</b></a></td>
# 	<td><b>|</b> <a href="dataQuerySelector.jsp?query=studentTab" target="detail"><b>ตารางเรียน</b></a></td>
# 	<td><b>|</b> <a href="dataQuerySelector.jsp?query=examTab" target="detail"><b>ตารางสอบ</b></a></td>
# 	<td><b>|</b> <a href="dataQuerySelector.jsp?query=roomTab" target="detail"><b>การใช้งานห้องเรียน</b></a> </td>
# 	<td><b>|</b> <a href="dataQuerySelector.jsp?query=openSectionTab" target="detail"><b>ตอนเรียนที่เปิด</b></a> <b>|</b> </td>
# </tr>
# </table>
# </center>
#
# </body>
# </html>
#
#
# <table border="0" width="100%" align="center">
# <tr align="center" bgcolor="#1E90FF"><td>
# 	<font size="+1" color="#FFFFFF"><b>ตารางสอบ</b></font>
# </td></tr>
#
# <tr><td>
# 	<form method="post" action="">
# 	<table align="center" border="0">
# 	<tr><td align="right"><b>คณะ </b></td>
# 	<td><select name="facCode" onChange="form.submit()">
# 	<option value="">- - - เลือกคณะ - - -</option>
#
# 		<option value="01"
# 		>
# 			01 คณะวิศวกรรมศาสตร์
# 		</option>
#
# 		<option value="02"
# 		>
# 			02 คณะครุศาสตร์อุตสาหกรรม
# 		</option>
#
# 		<option value="03"
# 		>
# 			03 วิทยาลัยเทคโนโลยีอุตสาหกรรม
# 		</option>
#
# 		<option value="04"
# 		>
# 			04 คณะวิทยาศาสตร์ประยุกต์
# 		</option>
#
# 		<option value="05"
# 		>
# 			05 คณะอุตสาหกรรมเกษตร
# 		</option>
#
# 		<option value="06"
# 		>
# 			06 คณะเทคโนโลยีและการจัดการอุตสาหกรรม
# 		</option>
#
# 		<option value="07"
# 		>
# 			07 คณะเทคโนโลยีสารสนเทศและนวัตกรรมดิจิทัล
# 		</option>
#
# 		<option value="08"
# 		>
# 			08 คณะศิลปศาสตร์ประยุกต์
# 		</option>
#
# 		<option value="09"
# 		>
# 			09 บัณฑิตวิทยาลัยวิศวกรรมศาสตร์นานาชาติฯ
# 		</option>
#
# 		<option value="10"
# 		>
# 			10 บัณฑิตวิทยาลัย
# 		</option>
#
# 		<option value="11"
# 		>
# 			11 คณะสถาปัตยกรรมและการออกแบบ
# 		</option>
#
# 		<option value="12"
# 		>
# 			12 คณะวิศวกรรมศาสตร์และเทคโนโลยี
# 		</option>
#
# 		<option value="13"
# 		>
# 			13 คณะวิทยาศาสตร์ พลังงานและสิ่งแวดล้อม
# 		</option>
#
# 		<option value="14"
# 		>
# 			14 คณะบริหารธุรกิจ
# 		</option>
#
# 		<option value="15"
# 		>
# 			15 วิทยาลัยนานาชาติ
# 		</option>
#
# 		<option value="16"
# 		>
# 			16 คณะพัฒนาธุรกิจและอุตสาหกรรม
# 		</option>
#
# 		<option value="17"
# 		>
# 			17 คณะบริหารธุรกิจและอุตสาหกรรมบริการ
# 		</option>
#
# 		<option value="18"
# 		>
# 			18 อุทยานเทคโนโลยี
# 		</option>
#
# 	</select></td></tr>
#
# 	<tr><td align="right"><b>หลักสูตร </b></td>
# 	<td><select name="currCode" onChange="form.submit()">
# 	<option value="">- - - เลือกหลักสูตร - - -</option>
#
# 	</select></td></tr>
# 	</table>
# 	</form>
# </td></tr>
# </table>
#
#
#
#
#
# None

# %%
from bs4 import BeautifulSoup

# Read the HTML file
with open("dataQuerySelector.html", "r",encoding="cp874") as f:
    content = f.read()

# Use BeautifulSoup to parse the HTML content
soup = BeautifulSoup(content, "html.parser")

# Find the table in the HTML document
table = soup.find_all("table")[4]

x=0
# Extract the rows and cells of the table
rows = table.find_all("tr")
for row in rows:
    cells = row.find_all("td")
    for cell in cells:
        if x <3:
            x+=1
        else:
            print(cell.text.strip())
# Out:
# 010113138 CIRCUITS AND ELECTRONICS
# 		3(3-0)
#
# พฤ. 30/3/2566  13:00-16:00
# 010113139 CIRCUITS AND ELECTRONICS LAB
# 		1(0-1)
#
#
# 010113941 PROJECT I
# 		3(0-3)
#
#
# 010113942 PROJECT II
# 		3(0-3)
#
#
# 010123103 ALGORITHMS AND DATA STRUCTUR
# 		3(2-1)
#
# จ. 3/4/2566  13:00-16:00
# 010123118 COMPUTER NETWORKS
# 		3(3-0)
#
# อ. 28/3/2566  9:00-12:00
# 010123120 EMBEDDED SYSTEM DESIGN LABOR
# 		1(0-1)
#
#
# 010123121 DATABASE SYSTEMS
# 		3(3-0)
#
# จ. 27/3/2566  9:00-12:00
# 010123124 COMPUTER ENGINEERING SEMINAR
# 		2(1-1)
#
#
# 010123128 COMPUTER NETWORKS LABORATORY
# 		1(0-1)
#
#
# 010123132 SOFTWARE DEVELOPMENT PRACTIC
# 		3(0-3)
#
#
# 010123134 COMPUTER ORGANIZATION
# 		3(3-0)
#
# ศ. 7/4/2566  9:00-12:00
# พ. 29/3/2566  9:00-12:00
# 080303701 DESIGN THINKING
# 		3(3-0)

# %%
import sqlite3
from bs4 import BeautifulSoup

# Read the HTML file with the correct encoding
with open("dataQuerySelector.html", "r", encoding="cp874") as f:
    content = f.read()

# Use BeautifulSoup to parse the HTML content
soup = BeautifulSoup(content, "html.parser")

# Find the table in the HTML document
table = soup.find("table")

# Extract the rows and cells of the table
rows = table.find_all("tr")

# Connect to the database
conn = sqlite3.connect("db.sqlite3")
c = conn.cursor()

# Create the table if it doesn't exist
c.execute("CREATE TABLE IF NOT EXISTS courses (code TEXT, name TEXT, credit TEXT, date TEXT, time TEXT)")

# Loop through each row of the table and insert the data into the database
for row in rows:
    cells = row.find_all("td")
    if len(cells) == 4:
        print('1')
        code = cells[0].text.strip()
        name = cells[1].text.strip()
        credit = cells[2].text.strip()
        date_time = cells[3].text.strip().split()
        date = date_time[0]
        time = date_time[1]
        c.execute("INSERT INTO courses (code, name, credit, date, time) VALUES (?, ?, ?, ?, ?)", (code, name, credit, date, time))

# Commit the changes and close the connection
conn.commit()
conn.close()

# %%
from bs4 import BeautifulSoup
import re
# Read the HTML file
with open("dataQuerySelector.html", "r",encoding="cp874") as f:
    content = f.read()

# Use BeautifulSoup to parse the HTML content
soup = BeautifulSoup(content, "html.parser")

# Find the table in the HTML document
table = soup.find_all("table")[4]

x=0
y=0

pattern = r"(\d+)([A-Za-z ]+)"


# Extract the rows and cells of the table
rows = table.find_all("tr")
for row in rows:
    if x <1:
        x+=1
    else:
        cells = row.find_all("td")
        for cell in cells:
            if y==0:
                print(cell.text)
'''                course_code_str = cell.text
                match = re.match(pattern, course_code_str)
                if match:
                    num_code = match.group(1)
                    text_code = match.group(2)
                print("Numeric code:", num_code)
                print("Text code:", text_code)
                y+=1
            elif y==1:
                print(cell.text +"\n")
                y+=1
            elif y==2:
                print(cell.text+"\n")
                y+=1
            elif y==4:
                print(cell.text+"\n")
                y=0'''
# Out:
# 		010113138 CIRCUITS AND ELECTRONICS
# 		3(3-0)
#
# พฤ. 30/3/2566  13:00-16:00
#
# 		010113139 CIRCUITS AND ELECTRONICS LAB
# 		1(0-1)
#
#
#
# 		010113941 PROJECT I
# 		3(0-3)
#
#
#
# 		010113942 PROJECT II
# 		3(0-3)
#
#
#
# 		010123103 ALGORITHMS AND DATA STRUCTUR
# 		3(2-1)
#
# จ. 3/4/2566  13:00-16:00
#
# 		010123118 COMPUTER NETWORKS
# 		3(3-0)
#
# อ. 28/3/2566  9:00-12:00
#
# 		010123120 EMBEDDED SYSTEM DESIGN LABOR
# 		1(0-1)
#
#
#
# 		010123121 DATABASE SYSTEMS
# 		3(3-0)
#
# จ. 27/3/2566  9:00-12:00
#
# 		010123124 COMPUTER ENGINEERING SEMINAR
# 		2(1-1)
#
#
#
# 		010123128 COMPUTER NETWORKS LABORATORY
# 		1(0-1)
#
#
#
# 		010123132 SOFTWARE DEVELOPMENT PRACTIC
# 		3(0-3)
#
#
#
# 		010123134 COMPUTER ORGANIZATION
# 		3(3-0)
#
# ศ. 7/4/2566  9:00-12:00
#
# 		010123135 LINEAR ALGEBRA
# 		3(3-0)
#
# ศ. 31/3/2566  13:00-16:00
#
# 		010123201 NUMERICAL METHODS FOR COMPUT
# 		3(3-0)
#
# อ. 28/3/2566  13:00-16:00
#
# 		010123213 ARTIFICIAL INTELLIGENCE
# 		3(3-0)
#
# อ. 4/4/2566  9:00-12:00
#
# 		010123224 REAL TIME OPERATION SYSTEMS
# 		3(3-0)
#
# อ. 4/4/2566  13:00-16:00
#
# 		010123301 PRE-COOPERATIVE EDUCATION
# 		2(1-1)
#
#
#
# 		010123303 CO-OPERATIVE EDUCATION II
# 		3(0-3)
#
#
#
# 		040203100 GENERAL MATHEMATICS
# 		3(3-0)
# อ. 31/1/2566 9:00-12:00
# อ. 4/4/2566  9:00-12:00
#
# 		040203111 ENGINEERING MATHEMATICS I
# 		3(3-0)
# จ. 30/1/2566 9:00-12:00
# ศ. 31/3/2566  9:00-12:00
#
# 		040203112 ENGINEERING MATHEMATICS II
# 		3(3-0)
# จ. 30/1/2566 9:00-12:00
# ศ. 31/3/2566  9:00-12:00
#
# 		040313005 PHYSICS I
# 		3(3-0)
# ศ. 3/2/2566 9:00-12:00
# จ. 27/3/2566  9:00-12:00
#
# 		040313007 PHYSICS II
# 		3(3-0)
# ศ. 3/2/2566 9:00-12:00
# จ. 27/3/2566  9:00-12:00
#
# 		040313008 PHYSICS LABORATORY II
# 		1(0-1)
#
# จ. 27/3/2566  13:00-15:00
#
# 		040503001 STATISTICS IN EVERYDAY LIFE
# 		3(3-0)
# พ. 1/2/2566 9:00-12:00
# ศ. 7/4/2566  9:00-12:00
#
# 		080103002 ENGLISH II
# 		3(3-0)
# พฤ. 2/2/2566 9:00-12:00
# อ. 28/3/2566  9:00-12:00
#
# 		080103018 ENGLISH FOR WORK
# 		3(3-0)
# จ. 30/1/2566 9:00-12:00
# พ. 29/3/2566  9:00-12:00
#
# 		080103034 ENGLISH CONVERSATION
# 		3(3-0)
#
#
#
# 		080203901 MAN AND SOCIETY
# 		3(3-0)
# อ. 31/1/2566 13:00-15:00
# จ. 27/3/2566  13:00-16:00
#
# 		080203905 ECONOMY AND EVERYDAY LIFE
# 		3(3-0)
# อ. 31/1/2566 13:00-15:00
# พฤ. 30/3/2566  13:00-16:00
#
# 		080203906 ECONOMICS FOR INDIVIDUAL DEV
# 		3(3-0)
# อ. 31/1/2566 13:00-15:00
# อ. 28/3/2566  13:00-16:00
#
# 		080203907 BUSINESS AND EVERYDAY LIFE
# 		3(3-0)
# อ. 31/1/2566 13:00-15:00
# อ. 28/3/2566  13:00-16:00
#
# 		080303103 PSYCHOLOGY FOR HAPPY LIFE
# 		3(3-0)
# อ. 31/1/2566 13:00-16:00
# พ. 29/3/2566  9:00-12:00
#
# 		080303501 BASKETBALL
# 		1(0-1)
#
#
#
# 		080303502 VOLLEYBALL
# 		1(0-1)
#
#
#
# 		080303505 TABLE TENNIS
# 		1(0-1)
#
#
#
# 		080303601 HUMAN RELATIONS
# 		3(3-0)
# จ. 30/1/2566 13:00-16:00
# พ. 29/3/2566  9:00-12:00
#
# 		080303701 DESIGN THINKING
# 		3(3-0)
# '                course_code_str = cell.text\n                match = re.match(pattern, course_code_str)\n                if match:\n                    num_code = match.group(1)\n                    text_code = match.group(2)\n                print("Numeric code:", num_code)\n                print("Text code:", text_code)\n                y+=1\n            elif y==1:\n                print(cell.text +"\n")\n                y+=1\n            elif y==2:\n                print(cell.text+"\n")\n                y+=1\n            elif y==4:\n                print(cell.text+"\n")\n                y=0'

# %%
from bs4 import BeautifulSoup

# Read the HTML file
with open("dataQuerySelector.html", "r",encoding="cp874") as f:
    content = f.read()

# Use BeautifulSoup to parse the HTML content
soup = BeautifulSoup(content, "html.parser")

# Find the table in the HTML document
table = soup.find_all("table")[4]

x=0
y=0
rows = table.find_all("tr")
for row in rows:
    if x <1:
        x+=1
    else:
        cells = row.find_all("td")
        for cell in cells:
            if y ==0 :
                print("h"+cell.text)
                y+=1
            elif y ==1 :
                print("y"+cell.text)
                y+=1
            else :
                print("z"+cell.text)
                y+=0
# Out:
# h
# 		010113138 CIRCUITS AND ELECTRONICS
# 		3(3-0)
# y
# zพฤ. 30/3/2566  13:00-16:00
# z
# 		010113139 CIRCUITS AND ELECTRONICS LAB
# 		1(0-1)
# z
# z
# z
# 		010113941 PROJECT I
# 		3(0-3)
# z
# z
# z
# 		010113942 PROJECT II
# 		3(0-3)
# z
# z
# z
# 		010123103 ALGORITHMS AND DATA STRUCTUR
# 		3(2-1)
# z
# zจ. 3/4/2566  13:00-16:00
# z
# 		010123118 COMPUTER NETWORKS
# 		3(3-0)
# z
# zอ. 28/3/2566  9:00-12:00
# z
# 		010123120 EMBEDDED SYSTEM DESIGN LABOR
# 		1(0-1)
# z
# z
# z
# 		010123121 DATABASE SYSTEMS
# 		3(3-0)
# z
# zจ. 27/3/2566  9:00-12:00
# z
# 		010123124 COMPUTER ENGINEERING SEMINAR
# 		2(1-1)
# z
# z
# z
# 		010123128 COMPUTER NETWORKS LABORATORY
# 		1(0-1)
# z
# z
# z
# 		010123132 SOFTWARE DEVELOPMENT PRACTIC
# 		3(0-3)
# z
# z
# z
# 		010123134 COMPUTER ORGANIZATION
# 		3(3-0)
# z
# zศ. 7/4/2566  9:00-12:00
# z
# 		010123135 LINEAR ALGEBRA
# 		3(3-0)
# z
# zศ. 31/3/2566  13:00-16:00
# z
# 		010123201 NUMERICAL METHODS FOR COMPUT
# 		3(3-0)
# z
# zอ. 28/3/2566  13:00-16:00
# z
# 		010123213 ARTIFICIAL INTELLIGENCE
# 		3(3-0)
# z
# zอ. 4/4/2566  9:00-12:00
# z
